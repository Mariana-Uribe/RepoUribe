# %%
def fun(n):
    if n>18:
        print('Es mayor de edad.')
    else:
        print('Es menor de edad.')

fun(20)
# Out:
# Es mayor de edad.

# %%
print('Saludo desde el Jean Paul')

# %%
print('saludos desde local Mariana')
